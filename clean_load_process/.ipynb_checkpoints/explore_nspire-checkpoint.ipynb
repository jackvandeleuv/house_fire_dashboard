# %%
import pandas as pd
from typing import *
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display, Markdown

pd.set_option('display.max_columns', None)

# %% [markdown]
# # Aggregate NSPIRE
# The goal of this notebook is to aggregate NSPIRE demo data at the locality level (city, town, village, etc.)

# %%
nspire = pd.read_csv('../data/nspire_demo_deficiencies.csv',
                     low_memory=False)

# %% [markdown]
# # Basic cleaning

# %%
nspire.loc[:, nspire.columns[:20]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77320 entries, 0 to 77319
# Data columns (total 20 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Unit                                      77320 non-null  object
#  1   NSPIRE Health & Safety                    66820 non-null  object
#  2   Deficiency Details                        77248 non-null  object
#  3   Question Template: Question Template ID   77248 non-null  object
#  4   Inspection ID                             77320 non-null  object
#  5   Deficiency ID                             77248 non-null  object
#  6   Room/Location                             77185 non-null  object
#  7   Mitigation Details                        32461 non-null  object
#  8   Mitigation Reviewer Comment               3420 non-null   object
#  9   Mitigation Late (Y/N)                     0 non-null      float64
#  10  Location (Unit/Inside/Outside)            77245 non-null  object
#  11  Reviewer Comment                          1192 non-null   object
#  12  Reviewer Finding(s)                       466 non-null    object
#  13  Room                                      0 non-null      float64
#  14  Unit Address                              57889 non-null  object
#  15  Status                                    77248 non-null  object
#  16  Inspector: Full Name                      0 non-null      float64
#  17  Inspectable Area                          77245 non-null  object
#  18  H&S Determination (LT-24hr / Std 30 Day)  77220 non-null  object
#  19  Deficiency Location Address               64034 non-null  object
# dtypes: float64(3), object(17)
# memory usage: 11.8+ MB

# %%
nspire.loc[:, nspire.columns[20:]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77320 entries, 0 to 77319
# Data columns (total 19 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Date/Time Mitigated                    32461 non-null  object
#  1   Deficiency Reviewed By: Full Name      4536 non-null   object
#  2   Mitigation Date (PHA/POA Input)        0 non-null      float64
#  3   Deficiency Comments                    77220 non-null  object
#  4   PropertyId                             77248 non-null  object
#  5   NSPIRE Standards                       77248 non-null  object
#  6   Defect Recorded Date/Time              77248 non-null  object
#  7   Date/Time Mitigation Reviewed          4536 non-null   object
#  8   Date/Time Mitigation Submitted         32461 non-null  object
#  9   Field Office Acknowledge (Date)        0 non-null      float64
#  10  Description of Repair (PHA/POA input)  0 non-null      float64
#  11  Corrective Timeframe                   66843 non-null  object
#  12  Codes                                  77222 non-null  object
#  13  Defect Recorded Date                   77248 non-null  object
#  14  Shipping Address                       77265 non-null  object
#  15  Shipping City                          77038 non-null  object
#  16  Shipping Street                        76186 non-null  object
#  17  Shipping State/Province                77240 non-null  object
#  18  Shipping Zip/Postal Code               76626 non-null  object
# dtypes: float64(3), object(16)
# memory usage: 11.2+ MB

# %% [markdown]
# Split deficiency details into separate columns.

# %%
def split_by_arrow(string: str) -> List[str]:
    if pd.isna(string):
        return [np.nan, np.nan, np.nan]  # Return a list of NaNs if the string is NaN
    else:
        split_string = string.split('->')
        # If there are less than 3 substrings, prepend the list with NaNs
        while len(split_string) < 4:
            split_string.insert(0, np.nan)
        return split_string

nspire_details = nspire['Deficiency Details'].apply(split_by_arrow).apply(pd.Series)
nspire_details = nspire_details.rename(columns = {0: 'details1', 1: 'details2', 2: 'details3', 3: 'details4'})
nspire = pd.concat([nspire, nspire_details], axis=1)

# %% [markdown]
# Standardize and remove bad state name values.

# %%
nspire['Shipping State/Province'].unique()
# Out:
# array(['OK', 'CO', 'CA', 'MA', 'TX', 'LA', 'KY', 'IL', 'TN', 'NC', 'MD',
#        'AL', 'CT', 'PA', 'UT', 'MO', 'NE', 'NY', 'SC', 'MS', 'FL', 'RI',
#        nan, 'GA', 'IN', 'WA', 'DE', 'AR', 'NJ', 'MI', 'NH', 'NV', 'WI',
#        'VA', 'AZ', 'VT', 'OH', 'MN', 'KS', 'What is your favorite movie?',
#        'SD', 'ME', 'ON', 'WV', 'pa', 'IA', 'OR', 'MT', 'NM', 'ND'],
#       dtype=object)

# %%
nspire['Shipping State/Province'] = nspire['Shipping State/Province'].str.upper()

# %%
print(len(nspire))

nspire = nspire[nspire['Shipping State/Province'].apply(
    lambda x: True if pd.isna(x) or len(str(x)) <= 2 else False
)]

print(len(nspire))
# Out:
# 77320
# 77307

# %%
nspire['Shipping City'] = nspire['Shipping City'].str.upper()

# %% [markdown]
# # Looking at structure of the dataset

# %% [markdown]
# It seems that the dataset has one row for every deficiency identified. Let's verify this.

# %%
inspections = nspire.groupby('Inspection ID').size()
inspections.sort_values()
# Out:
# Inspection ID
# INSP-00108      1
# INSP-01928      1
# INSP-01096      1
# INSP-01927      1
# INSP-01924      1
#              ...
# INSP-03032    169
# INSP-02613    170
# INSP-01165    182
# INSP-03067    187
# INSP-03079    200
# Length: 2993, dtype: int64

# %% [markdown]
# Each inspection has various amounts of deficiencies that were discovered.

# %%
inspections.describe()
# Out:
# count    2993.000000
# mean       25.829268
# std        26.552036
# min         1.000000
# 25%         7.000000
# 50%        17.000000
# 75%        35.000000
# max       200.000000
# dtype: float64

# %% [markdown]
# Here's an example of one inspection with multiple deficiency found and mitigated.

# %%
# nspire[nspire['Date/Time Mitigated'].notna()]
nspire[nspire.Unit == 'THE TOWERS APARTMENTS']
# Out:
#                        Unit       NSPIRE Health & Safety  \
# 0     THE TOWERS APARTMENTS  Severe Non-Life-Threatening
# 16    THE TOWERS APARTMENTS                     Standard
# 32    THE TOWERS APARTMENTS                     Standard
# 48    THE TOWERS APARTMENTS                     Standard
# 64    THE TOWERS APARTMENTS                     Standard
# 80    THE TOWERS APARTMENTS                     Standard
# 96    THE TOWERS APARTMENTS                     Standard
# 112   THE TOWERS APARTMENTS                     Standard
# 128   THE TOWERS APARTMENTS                     Standard
# 144   THE TOWERS APARTMENTS                     Standard
# 160   THE TOWERS APARTMENTS  Severe Non-Life-Threatening
# 176   THE TOWERS APARTMENTS  Severe Non-Life-Threatening
# 192   THE TOWERS APARTMENTS                     Standard
# 208   THE TOWERS APARTMENTS             Life-Threatening
# 240   THE TOWERS APARTMENTS                     Standard
# 384   THE TOWERS APARTMENTS                     Standard
# 400   THE TOWERS APARTMENTS                     Standard
# 784   THE TOWERS APARTMENTS                          NaN
# 992   THE TOWERS APARTMENTS                     Standard
# 1024  THE TOWERS APARTMENTS                          NaN
# 1040  THE TOWERS APARTMENTS                     Standard
# 1056  THE TOWERS APARTMENTS                     Standard
# 1072  THE TOWERS APARTMENTS  Severe Non-Life-Threatening
# 1136  THE TOWERS APARTMENTS                     Standard
# 1664  THE TOWERS APARTMENTS                     Standard
# 1824  THE TOWERS APARTMENTS                     Standard
# 1840  THE TOWERS APARTMENTS                     Standard
# 1920  THE TOWERS APARTMENTS                     Standard
# 2352  THE TOWERS APARTMENTS                     Standard
# 2384  THE TOWERS APARTMENTS                     Standard
# 2416  THE TOWERS APARTMENTS                     Standard
# 3264  THE TOWERS APARTMENTS                     Standard
# 3408  THE TOWERS APARTMENTS                     Standard
# 3424  THE TOWERS APARTMENTS                     Standard
#
#                                      Deficiency Details  \
# 0     Inside -> Exit Sign -> Lighted exit sign does ...
# 16    Inside -> Handrail -> Handrail is not secure -...
# 32    Inside -> Floor Covering and Finish -> Floor c...
# 48    Inside -> Ceiling -> Ceiling has an unstable s...
# 64    Inside -> Floor Covering and Finish -> Floor s...
# 80    Inside -> Floor Covering and Finish -> Floor c...
# 96    Outside -> Lighting - Exterior -> A permanentl...
# 112   Outside -> Handrail -> Handrail is not secure ...
# 128   Outside -> Lighting - Exterior -> A permanentl...
# 144   Outside -> Roof Assembly -> Gutter component i...
# 160   Inside -> Door - Fire Labeled -> Fire labeled ...
# 176   Inside -> Sharp Edges -> A sharp edge that can...
# 192   Inside -> Lighting - Interior -> A permanently...
# 208   Inside -> Electrical - Outlet and Switch -> Ou...
# 240   Unit -> Refrigerator -> Refrigerator component...
# 384   Inside -> Ceiling -> Ceiling has a hole -> A h...
# 400   Outside -> Wall Covering and Finish - Exterior...
# 784   Inside -> Lighting - Auxiliary -> Auxiliary li...
# 992   Unit -> Refrigerator -> Refrigerator is inoper...
# 1024  Unit -> Door - Entry -> Entry door component i...
# 1040  Unit -> Cooking Appliance -> Cooking range, co...
# 1056  Unit -> Ceiling -> Ceiling has an unstable sur...
# 1072  Unit -> Bathtub and Shower -> Only 1 bathtub o...
# 1136  Unit -> Infestation -> Evidence of cockroaches...
# 1664  Unit -> Infestation -> Evidence of cockroaches...
# 1824  Unit -> Infestation -> Evidence of cockroaches...
# 1840  Unit -> Infestation -> Evidence of bedbugs -> ...
# 1920  Unit -> Leak -> Plumbing leaks -> Failure of a...
# 2352  Unit -> Wall Covering and Finish - Interior ->...
# 2384  Unit -> Infestation -> Evidence of cockroaches...
# 2416  Unit -> Infestation -> Evidence of bedbugs -> ...
# 3264  Unit -> Refrigerator -> Refrigerator is inoper...
# 3408  Unit -> Cooking Appliance -> Cooking range, co...
# 3424  Unit -> Refrigerator -> Refrigerator is inoper...
#
#      Question Template: Question Template ID Inspection ID Deficiency ID  \
# 0                                    Q-86826    INSP-01563    QR-5715325
# 16                                   Q-86898    INSP-01563    QR-5715772
# 32                                   Q-86848    INSP-01563    QR-5715780
# 48                                   Q-86624    INSP-01563    QR-5715784
# 64                                   Q-86844    INSP-01563    QR-5715788
# 80                                   Q-86848    INSP-01563    QR-5715776
# 96                                   Q-86480    INSP-01563    QR-5715829
# 112                                  Q-86450    INSP-01563    QR-5715833
# 128                                  Q-86480    INSP-01563    QR-5715837
# 144                                  Q-86508    INSP-01563    QR-5715841
# 160                                  Q-86760    INSP-01563    QR-5715623
# 176                                  Q-86975    INSP-01563    QR-5715627
# 192                                  Q-86962    INSP-01563    QR-5715631
# 208                                  Q-86794    INSP-01563    QR-5715635
# 240                                  Q-86180    INSP-01563    QR-5718751
# 384                                  Q-86632    INSP-01563    QR-5715431
# 400                                  Q-86534    INSP-01563    QR-5715474
# 784                                  Q-86960    INSP-01563    QR-5715985
# 992                                  Q-86179    INSP-01563    QR-5717227
# 1024                                 Q-85981    INSP-01563    QR-5717708
# 1040                                 Q-85923    INSP-01563    QR-5717712
# 1056                                 Q-85875    INSP-01563    QR-5717716
# 1072                                 Q-86235    INSP-01563    QR-5717720
# 1136                                 Q-86133    INSP-01563    QR-5716732
# 1664                                 Q-86133    INSP-01563    QR-5718950
# 1824                                 Q-86133    INSP-01563    QR-5718553
# 1840                                 Q-86137    INSP-01563    QR-5718165
# 1920                                 Q-86168    INSP-01563    QR-5718652
# 2352                                 Q-86215    INSP-01563    QR-5716491
# 2384                                 Q-86133    INSP-01563    QR-5718851
# 2416                                 Q-86137    INSP-01563    QR-5717085
# 3264                                 Q-86179    INSP-01563    QR-5717864
# 3408                                 Q-85931    INSP-01563    QR-5718457
# 3424                                 Q-86179    INSP-01563    QR-5718453
#
#                Room/Location  \
# 0     Halls/Corridors/Stairs
# 16    Halls/Corridors/Stairs
# 32    Halls/Corridors/Stairs
# 48                     Lobby
# 64    Halls/Corridors/Stairs
# 80    Halls/Corridors/Stairs
# 96                Exterior S
# 112               Exterior S
# 128               Exterior S
# 144               Exterior W
# 160   Halls/Corridors/Stairs
# 176   Halls/Corridors/Stairs
# 192   Halls/Corridors/Stairs
# 208   Halls/Corridors/Stairs
# 240                  Kitchen
# 384   Halls/Corridors/Stairs
# 400           Garage/Carport
# 784   Halls/Corridors/Stairs
# 992                  Kitchen
# 1024   Entryway (Front/Rear)
# 1040                 Kitchen
# 1056                 Kitchen
# 1072              Bathroom 1
# 1136                 Kitchen
# 1664                 Kitchen
# 1824                 Kitchen
# 1840                 Kitchen
# 1920                 Kitchen
# 2352               Bedroom 1
# 2384                 Kitchen
# 2416                 Kitchen
# 3264                 Kitchen
# 3408                 Kitchen
# 3424                 Kitchen
#
#                                      Mitigation Details  \
# 0                                       Exit sign fixed
# 16                    Tighten hand rail;Work Completed.
# 32    Requested Tech Service Dept. to secure floorin...
# 48    Tore out oils Sheetrock and replaced with new....
# 64    Floor tile completed by contractor;Work Comple...
# 80    Asked Technical Service Department to secure c...
# 96          Light fixture was replaced.;Work Completed.
# 112   Shimmed rails with large thick block to keep f...
# 128          Light fixture was replaced;Work Completed.
# 144   Removed damaged sheet metal from downspout. In...
# 160   removed all door hardware, covered holes with ...
# 176            swept up glass and removed broken bottle
# 192   Rehung light in catwalk that had been ripped d...
# 208                    replaced cover plates in catwalk
# 240               Replaced refrigerator;Work Completed.
# 384   Repaired ceiling. Found the missing tile and t...
# 400   Installed panels in the carport ceiling;Work C...
# 784     Replaced aux light in stairwell;Work Completed.
# 992   snapped refrigerator door seal back into place...
# 1024  Replaced door knob and backset on entry door;W...
# 1040  Swapped out the power cord to the range and in...
# 1056         Repaired kitchen ceiling. Painted ceiling.
# 1072  ran K50 machine from 3 different locations and...
# 1136  unit was treated when entire building was trea...
# 1664  unit was treated for roaches when entire build...
# 1824  unit treated when entire building was treated ...
# 1840  Sprayed apt for bedbugs with eco raider.;Work ...
# 1920             Replaced p trap (used);Work Completed.
# 2352  removed broken sheet rock measure and cut new ...
# 2384  unit was treated for roaches when entire build...
# 2416  inspected for bedbugs unit is clear at this ti...
# 3264         Replaced door seal gaskets;Work Completed.
# 3408  Delivered new range to apartment. Removed powe...
# 3424          installed 40w light bulb in refrigerator.
#
#                             Mitigation Reviewer Comment  \
# 0     Photo submitted of mitigation. The light is on...
# 16                                                  NaN
# 32                                                  NaN
# 48                                                  NaN
# 64                                                  NaN
# 80                                                  NaN
# 96                                                  NaN
# 112                                                 NaN
# 128                                                 NaN
# 144                                                 NaN
# 160                                                 NaN
# 176                                                 NaN
# 192                                                 NaN
# 208                                                 NaN
# 240                                                 NaN
# 384                                                 NaN
# 400                                                 NaN
# 784                                                 NaN
# 992                                                 NaN
# 1024                                                NaN
# 1040                                                NaN
# 1056                                                NaN
# 1072                                                NaN
# 1136                                                NaN
# 1664                                                NaN
# 1824                                                NaN
# 1840                                                NaN
# 1920                                                NaN
# 2352                                                NaN
# 2384                                                NaN
# 2416                                                NaN
# 3264                                                NaN
# 3408                                                NaN
# 3424                                                NaN
#
#       Mitigation Late (Y/N) Location (Unit/Inside/Outside)  \
# 0                       NaN                         Inside
# 16                      NaN                         Inside
# 32                      NaN                         Inside
# 48                      NaN                         Inside
# 64                      NaN                         Inside
# 80                      NaN                         Inside
# 96                      NaN                        Outside
# 112                     NaN                        Outside
# 128                     NaN                        Outside
# 144                     NaN                        Outside
# 160                     NaN                         Inside
# 176                     NaN                         Inside
# 192                     NaN                         Inside
# 208                     NaN                         Inside
# 240                     NaN                           Unit
# 384                     NaN                         Inside
# 400                     NaN                        Outside
# 784                     NaN                         Inside
# 992                     NaN                           Unit
# 1024                    NaN                           Unit
# 1040                    NaN                           Unit
# 1056                    NaN                           Unit
# 1072                    NaN                           Unit
# 1136                    NaN                           Unit
# 1664                    NaN                           Unit
# 1824                    NaN                           Unit
# 1840                    NaN                           Unit
# 1920                    NaN                           Unit
# 2352                    NaN                           Unit
# 2384                    NaN                           Unit
# 2416                    NaN                           Unit
# 3264                    NaN                           Unit
# 3408                    NaN                           Unit
# 3424                    NaN                           Unit
#
#                                        Reviewer Comment  \
# 0                                                   NaN
# 16                                                  NaN
# 32                                                  NaN
# 48                                                  NaN
# 64                                                  NaN
# 80                                                  NaN
# 96                                                  NaN
# 112                                                 NaN
# 128                                                 NaN
# 144                                                 NaN
# 160                                                 NaN
# 176                                                 NaN
# 192                                                 NaN
# 208   Recorded deficiency does not meet standard def...
# 240                                                 NaN
# 384                                                 NaN
# 400                                                 NaN
# 784                                                 NaN
# 992                                                 NaN
# 1024                                                NaN
# 1040                                                NaN
# 1056                                                NaN
# 1072                                                NaN
# 1136                                                NaN
# 1664                                                NaN
# 1824                                                NaN
# 1840                                                NaN
# 1920                                                NaN
# 2352                                                NaN
# 2384                                                NaN
# 2416                                                NaN
# 3264                                                NaN
# 3408                                                NaN
# 3424                                                NaN
#
#               Reviewer Finding(s)  Room  Unit Address  \
# 0                             NaN   NaN           NaN
# 16                            NaN   NaN           NaN
# 32                            NaN   NaN           NaN
# 48                            NaN   NaN           NaN
# 64                            NaN   NaN           NaN
# 80                            NaN   NaN           NaN
# 96                            NaN   NaN           NaN
# 112                           NaN   NaN           NaN
# 128                           NaN   NaN           NaN
# 144                           NaN   NaN           NaN
# 160                           NaN   NaN           NaN
# 176                           NaN   NaN           NaN
# 192                           NaN   NaN           NaN
# 208   Not Compliant With Standard   NaN           NaN
# 240                           NaN   NaN            2C
# 384                           NaN   NaN           NaN
# 400                           NaN   NaN           NaN
# 784                           NaN   NaN           NaN
# 992                           NaN   NaN           405
# 1024                          NaN   NaN           27A
# 1040                          NaN   NaN           27A
# 1056                          NaN   NaN           27A
# 1072                          NaN   NaN           27A
# 1136                          NaN   NaN           419
# 1664                          NaN   NaN           202
# 1824                          NaN   NaN           304
# 1840                          NaN   NaN  7A ALTERNATE
# 1920                          NaN   NaN          303A
# 2352                          NaN   NaN           201
# 2384                          NaN   NaN           203
# 2416                          NaN   NaN           407
# 3264                          NaN   NaN            24
# 3408                          NaN   NaN           305
# 3424                          NaN   NaN           305
#
#                                 Status  Inspector: Full Name Inspectable Area  \
# 0                  Mitigation Approved                   NaN           Inside
# 16    Evidence of Mitigation Submitted                   NaN           Inside
# 32    Evidence of Mitigation Submitted                   NaN           Inside
# 48    Evidence of Mitigation Submitted                   NaN           Inside
# 64    Evidence of Mitigation Submitted                   NaN           Inside
# 80    Evidence of Mitigation Submitted                   NaN           Inside
# 96    Evidence of Mitigation Submitted                   NaN          Outside
# 112   Evidence of Mitigation Submitted                   NaN          Outside
# 128   Evidence of Mitigation Submitted                   NaN          Outside
# 144   Evidence of Mitigation Submitted                   NaN          Outside
# 160   Evidence of Mitigation Submitted                   NaN           Inside
# 176   Evidence of Mitigation Submitted                   NaN           Inside
# 192   Evidence of Mitigation Submitted                   NaN           Inside
# 208   Evidence of Mitigation Submitted                   NaN           Inside
# 240   Evidence of Mitigation Submitted                   NaN             Unit
# 384   Evidence of Mitigation Submitted                   NaN           Inside
# 400   Evidence of Mitigation Submitted                   NaN          Outside
# 784   Evidence of Mitigation Submitted                   NaN           Inside
# 992   Evidence of Mitigation Submitted                   NaN             Unit
# 1024  Evidence of Mitigation Submitted                   NaN             Unit
# 1040  Evidence of Mitigation Submitted                   NaN             Unit
# 1056  Evidence of Mitigation Submitted                   NaN             Unit
# 1072  Evidence of Mitigation Submitted                   NaN             Unit
# 1136  Evidence of Mitigation Submitted                   NaN             Unit
# 1664  Evidence of Mitigation Submitted                   NaN             Unit
# 1824  Evidence of Mitigation Submitted                   NaN             Unit
# 1840  Evidence of Mitigation Submitted                   NaN             Unit
# 1920  Evidence of Mitigation Submitted                   NaN             Unit
# 2352  Evidence of Mitigation Submitted                   NaN             Unit
# 2384  Evidence of Mitigation Submitted                   NaN             Unit
# 2416  Evidence of Mitigation Submitted                   NaN             Unit
# 3264  Evidence of Mitigation Submitted                   NaN             Unit
# 3408  Evidence of Mitigation Submitted                   NaN             Unit
# 3424  Evidence of Mitigation Submitted                   NaN             Unit
#
#      H&S Determination (LT-24hr / Std 30 Day)  \
# 0        Severe Non-Life-Threatening 24 hours
# 16                           Standard 30 days
# 32                           Standard 30 days
# 48                           Standard 30 days
# 64                           Standard 30 days
# 80                           Standard 30 days
# 96                           Standard 30 days
# 112                          Standard 30 days
# 128                          Standard 30 days
# 144                          Standard 30 days
# 160      Severe Non-Life-Threatening 24 hours
# 176      Severe Non-Life-Threatening 24 hours
# 192                          Standard 30 days
# 208                 Life-Threatening 24 hours
# 240                          Standard 30 days
# 384                          Standard 30 days
# 400                          Standard 30 days
# 784                                   N/A N/A
# 992                          Standard 30 days
# 1024                                  N/A N/A
# 1040                         Standard 30 days
# 1056                         Standard 30 days
# 1072     Severe Non-Life-Threatening 24 hours
# 1136                         Standard 30 days
# 1664                         Standard 30 days
# 1824                         Standard 30 days
# 1840                         Standard 30 days
# 1920                         Standard 30 days
# 2352                         Standard 30 days
# 2384                         Standard 30 days
# 2416                         Standard 30 days
# 3264                         Standard 30 days
# 3408                         Standard 30 days
# 3424                         Standard 30 days
#
#                      Deficiency Location Address Date/Time Mitigated  \
# 0     913 NW 12th Street Oklahoma City, OK 73106  8/10/2022 12:30 PM
# 16     125 NW 9th Street Oklahoma City, OK 73102  8/11/2022 12:00 PM
# 32     125 NW 9th Street Oklahoma City, OK 73102   8/15/2022 4:00 PM
# 48     125 NW 9th Street Oklahoma City, OK 73102  8/18/2022 12:30 PM
# 64     125 NW 9th Street Oklahoma City, OK 73102   8/15/2022 4:30 PM
# 80     125 NW 9th Street Oklahoma City, OK 73102   8/15/2022 4:00 PM
# 96     125 NW 9th Street Oklahoma City, OK 73102   8/18/2022 7:30 AM
# 112    125 NW 9th Street Oklahoma City, OK 73102   8/15/2022 3:00 PM
# 128    125 NW 9th Street Oklahoma City, OK 73102   8/18/2022 7:45 AM
# 144    125 NW 9th Street Oklahoma City, OK 73102  8/23/2022 10:00 AM
# 160    135 NW 9th street Oklahoma City, OK 73102  8/10/2022 12:30 PM
# 176    135 NW 9th street Oklahoma City, OK 73102   8/10/2022 2:00 PM
# 192    135 NW 9th street Oklahoma City, OK 73102   8/11/2022 2:00 PM
# 208    135 NW 9th street Oklahoma City, OK 73102   8/10/2022 9:00 AM
# 240                                           2c  8/17/2022 12:00 PM
# 384      1014 N ROBINSON Oklahoma City, OK 73102  8/12/2022 10:30 AM
# 400      1014 N ROBINSON Oklahoma City, OK 73102  8/23/2022 11:00 AM
# 784    117 NW 9th Street Oklahoma City, OK 73102   8/15/2022 2:12 PM
# 992                                          405  8/11/2022 10:30 AM
# 1024                                         27A  8/17/2022 12:00 PM
# 1040                                         27A  8/17/2022 12:00 PM
# 1056                                         27A  8/17/2022 12:00 PM
# 1072                                         27A  8/10/2022 12:30 PM
# 1136                                         419   8/11/2022 5:00 PM
# 1664                                         202   8/18/2022 5:00 PM
# 1824                                         304   8/18/2022 2:16 PM
# 1840                                          7A   9/7/2022 11:00 AM
# 1920                                        303A   8/15/2022 2:00 PM
# 2352                                         201   8/29/2022 2:00 PM
# 2384                                         203   8/18/2022 5:00 PM
# 2416                                         407    9/6/2022 2:18 PM
# 3264                                          24  8/16/2022 12:00 PM
# 3408                                         305   8/11/2022 4:00 PM
# 3424                                         305    9/7/2022 4:30 PM
#
#      Deficiency Reviewed By: Full Name  Mitigation Date (PHA/POA Input)  \
# 0                   Zachary Dobelbower                              NaN
# 16                                 NaN                              NaN
# 32                                 NaN                              NaN
# 48                                 NaN                              NaN
# 64                                 NaN                              NaN
# 80                                 NaN                              NaN
# 96                                 NaN                              NaN
# 112                                NaN                              NaN
# 128                                NaN                              NaN
# 144                                NaN                              NaN
# 160                                NaN                              NaN
# 176                                NaN                              NaN
# 192                                NaN                              NaN
# 208                                NaN                              NaN
# 240                                NaN                              NaN
# 384                                NaN                              NaN
# 400                                NaN                              NaN
# 784                                NaN                              NaN
# 992                                NaN                              NaN
# 1024                               NaN                              NaN
# 1040                               NaN                              NaN
# 1056                               NaN                              NaN
# 1072                               NaN                              NaN
# 1136                               NaN                              NaN
# 1664                               NaN                              NaN
# 1824                               NaN                              NaN
# 1840                               NaN                              NaN
# 1920                               NaN                              NaN
# 2352                               NaN                              NaN
# 2384                               NaN                              NaN
# 2416                               NaN                              NaN
# 3264                               NaN                              NaN
# 3408                               NaN                              NaN
# 3424                               NaN                              NaN
#
#                                  Deficiency Comments       PropertyId  \
# 0                          Needs a battery 4th floor  0013d000008bJ27
# 16                     Loose on East tower 2nd floor  0013d000008bJ27
# 32                             2nd floor by unit 27a  0013d000008bJ27
# 48          Unstable due to prior leak in west tower  0013d000008bJ27
# 64    Due to electrical issue in unit 105 west tower  0013d000008bJ27
# 80                             East tower by unit 25  0013d000008bJ27
# 96                          East tower light damaged  0013d000008bJ27
# 112                Loose on front and back handrails  0013d000008bJ27
# 128                                      Broke light  0013d000008bJ27
# 144                                   Damaged gutter  0013d000008bJ27
# 160                          No latch or door handle  0013d000008bJ27
# 176                                      Broke glass  0013d000008bJ27
# 192                                 Needs reattached  0013d000008bJ27
# 208                                    Missing plate  0013d000008bJ27
# 240                             Freezer doesn't work  0013d000008bJ27
# 384                           Missing tile 3rd floor  0013d000008bJ27
# 400               Tenant truck punctured the ceiling  0013d000008bJ27
# 784                      1st floor missing aux light  0013d000008bJ27
# 992                                 Needs a new seal  0013d000008bJ27
# 1024                                Missing hardware  0013d000008bJ27
# 1040                        Oven and no burners work  0013d000008bJ27
# 1056                Bulge has water in it in ceiling  0013d000008bJ27
# 1072                                  Will not drain  0013d000008bJ27
# 1136                                         Roaches  0013d000008bJ27
# 1664                                         Roaches  0013d000008bJ27
# 1824                                         Roaches  0013d000008bJ27
# 1840                                 Throughout unit  0013d000008bJ27
# 1920             Leak under kitchen sink with p trap  0013d000008bJ27
# 2352                                    Hole in wall  0013d000008bJ27
# 2384                                         Roaches  0013d000008bJ27
# 2416                       Bed bugs all through unit  0013d000008bJ27
# 3264                       Needs top and bottom seal  0013d000008bJ27
# 3408                       Oven doesn't produce heat  0013d000008bJ27
# 3424                                   Needs a light  0013d000008bJ27
#
#                          NSPIRE Standards Defect Recorded Date/Time  \
# 0                               Exit Sign          8/9/2022 7:09 PM
# 16                               Handrail          8/9/2022 7:10 PM
# 32              Floor Covering and Finish          8/9/2022 7:10 PM
# 48                                Ceiling          8/9/2022 7:10 PM
# 64              Floor Covering and Finish          8/9/2022 7:10 PM
# 80              Floor Covering and Finish          8/9/2022 7:10 PM
# 96                    Lighting - Exterior          8/9/2022 7:10 PM
# 112                              Handrail          8/9/2022 7:10 PM
# 128                   Lighting - Exterior          8/9/2022 7:10 PM
# 144                         Roof Assembly          8/9/2022 7:10 PM
# 160                   Door - Fire Labeled          8/9/2022 7:09 PM
# 176                           Sharp Edges          8/9/2022 7:09 PM
# 192                   Lighting - Interior          8/9/2022 7:09 PM
# 208        Electrical - Outlet and Switch          8/9/2022 7:09 PM
# 240                          Refrigerator          8/9/2022 7:12 PM
# 384                               Ceiling          8/9/2022 7:09 PM
# 400   Wall Covering and Finish - Exterior          8/9/2022 7:09 PM
# 784                  Lighting - Auxiliary          8/9/2022 7:10 PM
# 992                          Refrigerator          8/9/2022 7:11 PM
# 1024                         Door - Entry          8/9/2022 7:11 PM
# 1040                    Cooking Appliance          8/9/2022 7:11 PM
# 1056                              Ceiling          8/9/2022 7:11 PM
# 1072                   Bathtub and Shower          8/9/2022 7:11 PM
# 1136                          Infestation          8/9/2022 7:10 PM
# 1664                          Infestation          8/9/2022 7:12 PM
# 1824                          Infestation          8/9/2022 7:12 PM
# 1840                          Infestation          8/9/2022 7:12 PM
# 1920                                 Leak          8/9/2022 7:12 PM
# 2352  Wall Covering and Finish - Interior          8/9/2022 7:10 PM
# 2384                          Infestation          8/9/2022 7:12 PM
# 2416                          Infestation          8/9/2022 7:11 PM
# 3264                         Refrigerator          8/9/2022 7:11 PM
# 3408                    Cooking Appliance          8/9/2022 7:12 PM
# 3424                         Refrigerator          8/9/2022 7:12 PM
#
#      Date/Time Mitigation Reviewed Date/Time Mitigation Submitted  \
# 0              10/25/2022 12:07 PM             8/10/2022 10:35 AM
# 16                             NaN              8/29/2022 2:45 PM
# 32                             NaN               9/2/2022 7:21 AM
# 48                             NaN               9/5/2022 8:03 PM
# 64                             NaN               9/2/2022 7:25 AM
# 80                             NaN               9/2/2022 7:19 AM
# 96                             NaN               9/7/2022 2:05 PM
# 112                            NaN               9/7/2022 2:07 PM
# 128                            NaN               9/7/2022 2:10 PM
# 144                            NaN               9/5/2022 8:00 PM
# 160                            NaN             8/10/2022 10:58 AM
# 176                            NaN             8/10/2022 12:50 PM
# 192                            NaN              8/29/2022 2:32 PM
# 208                            NaN             8/10/2022 10:53 AM
# 240                            NaN               9/7/2022 2:21 PM
# 384                            NaN              8/29/2022 2:23 PM
# 400                            NaN              8/29/2022 2:30 PM
# 784                            NaN               9/7/2022 2:12 PM
# 992                            NaN              8/29/2022 2:20 PM
# 1024                           NaN               9/7/2022 1:51 PM
# 1040                           NaN               9/7/2022 1:48 PM
# 1056                           NaN               9/7/2022 1:55 PM
# 1072                           NaN             8/10/2022 10:39 AM
# 1136                           NaN               9/2/2022 7:46 AM
# 1664                           NaN               9/2/2022 7:33 AM
# 1824                           NaN               9/7/2022 2:16 PM
# 1840                           NaN               9/7/2022 1:31 PM
# 1920                           NaN               9/7/2022 1:58 PM
# 2352                           NaN              8/29/2022 2:04 PM
# 2384                           NaN               9/2/2022 7:32 AM
# 2416                           NaN               9/7/2022 2:18 PM
# 3264                           NaN               9/7/2022 1:35 PM
# 3408                           NaN               9/7/2022 2:02 PM
# 3424                           NaN               9/9/2022 6:09 AM
#
#       Field Office Acknowledge (Date)  Description of Repair (PHA/POA input)  \
# 0                                 NaN                                    NaN
# 16                                NaN                                    NaN
# 32                                NaN                                    NaN
# 48                                NaN                                    NaN
# 64                                NaN                                    NaN
# 80                                NaN                                    NaN
# 96                                NaN                                    NaN
# 112                               NaN                                    NaN
# 128                               NaN                                    NaN
# 144                               NaN                                    NaN
# 160                               NaN                                    NaN
# 176                               NaN                                    NaN
# 192                               NaN                                    NaN
# 208                               NaN                                    NaN
# 240                               NaN                                    NaN
# 384                               NaN                                    NaN
# 400                               NaN                                    NaN
# 784                               NaN                                    NaN
# 992                               NaN                                    NaN
# 1024                              NaN                                    NaN
# 1040                              NaN                                    NaN
# 1056                              NaN                                    NaN
# 1072                              NaN                                    NaN
# 1136                              NaN                                    NaN
# 1664                              NaN                                    NaN
# 1824                              NaN                                    NaN
# 1840                              NaN                                    NaN
# 1920                              NaN                                    NaN
# 2352                              NaN                                    NaN
# 2384                              NaN                                    NaN
# 2416                              NaN                                    NaN
# 3264                              NaN                                    NaN
# 3408                              NaN                                    NaN
# 3424                              NaN                                    NaN
#
#      Corrective Timeframe                       Codes Defect Recorded Date  \
# 0                24 hours              r1, r2, m2, m3             8/9/2022
# 16                30 days                  r2, m1, m2             8/9/2022
# 32                30 days              r2, m1, m2, m4             8/9/2022
# 48                30 days                  r2, r6, m1             8/9/2022
# 64                30 days  r1, r2, r3, r6, m1, m2, m4             8/9/2022
# 80                30 days              r2, m1, m2, m4             8/9/2022
# 96                30 days                      r2, m2             8/9/2022
# 112               30 days                  r2, m1, m2             8/9/2022
# 128               30 days                      r2, m2             8/9/2022
# 144               30 days                  r2, r6, m1             8/9/2022
# 160              24 hours                  r2, r6, m2             8/9/2022
# 176              24 hours                      r2, m2             8/9/2022
# 192               30 days                      r2, m2             8/9/2022
# 208              24 hours                  r2, r6, m2             8/9/2022
# 240               30 days                  r1, r6, m1             8/9/2022
# 384               30 days          r1, r2, r6, r7, m1             8/9/2022
# 400               30 days                 r1, m2, pp1             8/9/2022
# 784                   NaN                          m2             8/9/2022
# 992               30 days                  r1, r6, m1             8/9/2022
# 1024                  NaN                          m1             8/9/2022
# 1040              30 days                  r2, r6, m1             8/9/2022
# 1056              30 days                  r2, r6, m1             8/9/2022
# 1072             24 hours                  r3, r6, m1             8/9/2022
# 1136              30 days              r1, r3, m1, m2             8/9/2022
# 1664              30 days              r1, r3, m1, m2             8/9/2022
# 1824              30 days              r1, r3, m1, m2             8/9/2022
# 1840              30 days                  r1, r3, m1             8/9/2022
# 1920              30 days  r1, r2, r3, r6, m1, m4, m6             8/9/2022
# 2352              30 days                  r1, r6, m2             8/9/2022
# 2384              30 days              r1, r3, m1, m2             8/9/2022
# 2416              30 days                  r1, r3, m1             8/9/2022
# 3264              30 days                  r1, r6, m1             8/9/2022
# 3408              30 days                  r2, r6, m1             8/9/2022
# 3424              30 days                  r1, r6, m1             8/9/2022
#
#                        Shipping Address  Shipping City Shipping Street  \
# 0     117 NW 9, OKLAHOMA CITY, OK 73102  OKLAHOMA CITY        117 NW 9
# 16    117 NW 9, OKLAHOMA CITY, OK 73102  OKLAHOMA CITY        117 NW 9
# 32    117 NW 9, OKLAHOMA CITY, OK 73102  OKLAHOMA CITY        117 NW 9
# 48    117 NW 9, OKLAHOMA CITY, OK 73102  OKLAHOMA CITY        117 NW 9
# 64    117 NW 9, OKLAHOMA CITY, OK 73102  OKLAHOMA CITY        117 NW 9
# 80    117 NW 9, OKLAHOMA CITY, OK 73102  OKLAHOMA CITY        117 NW 9
# 96    117 NW 9, OKLAHOMA CITY, OK 73102  OKLAHOMA CITY        117 NW 9
# 112   117 NW 9, OKLAHOMA CITY, OK 73102  OKLAHOMA CITY        117 NW 9
# 128   117 NW 9, OKLAHOMA CITY, OK 73102  OKLAHOMA CITY        117 NW 9
# 144   117 NW 9, OKLAHOMA CITY, OK 73102  OKLAHOMA CITY        117 NW 9
# 160   117 NW 9, OKLAHOMA CITY, OK 73102  OKLAHOMA CITY        117 NW 9
# 176   117 NW 9, OKLAHOMA CITY, OK 73102  OKLAHOMA CITY        117 NW 9
# 192   117 NW 9, OKLAHOMA CITY, OK 73102  OKLAHOMA CITY        117 NW 9
# 208   117 NW 9, OKLAHOMA CITY, OK 73102  OKLAHOMA CITY        117 NW 9
# 240   117 NW 9, OKLAHOMA CITY, OK 73102  OKLAHOMA CITY        117 NW 9
# 384   117 NW 9, OKLAHOMA CITY, OK 73102  OKLAHOMA CITY        117 NW 9
# 400   117 NW 9, OKLAHOMA CITY, OK 73102  OKLAHOMA CITY        117 NW 9
# 784   117 NW 9, OKLAHOMA CITY, OK 73102  OKLAHOMA CITY        117 NW 9
# 992   117 NW 9, OKLAHOMA CITY, OK 73102  OKLAHOMA CITY        117 NW 9
# 1024  117 NW 9, OKLAHOMA CITY, OK 73102  OKLAHOMA CITY        117 NW 9
# 1040  117 NW 9, OKLAHOMA CITY, OK 73102  OKLAHOMA CITY        117 NW 9
# 1056  117 NW 9, OKLAHOMA CITY, OK 73102  OKLAHOMA CITY        117 NW 9
# 1072  117 NW 9, OKLAHOMA CITY, OK 73102  OKLAHOMA CITY        117 NW 9
# 1136  117 NW 9, OKLAHOMA CITY, OK 73102  OKLAHOMA CITY        117 NW 9
# 1664  117 NW 9, OKLAHOMA CITY, OK 73102  OKLAHOMA CITY        117 NW 9
# 1824  117 NW 9, OKLAHOMA CITY, OK 73102  OKLAHOMA CITY        117 NW 9
# 1840  117 NW 9, OKLAHOMA CITY, OK 73102  OKLAHOMA CITY        117 NW 9
# 1920  117 NW 9, OKLAHOMA CITY, OK 73102  OKLAHOMA CITY        117 NW 9
# 2352  117 NW 9, OKLAHOMA CITY, OK 73102  OKLAHOMA CITY        117 NW 9
# 2384  117 NW 9, OKLAHOMA CITY, OK 73102  OKLAHOMA CITY        117 NW 9
# 2416  117 NW 9, OKLAHOMA CITY, OK 73102  OKLAHOMA CITY        117 NW 9
# 3264  117 NW 9, OKLAHOMA CITY, OK 73102  OKLAHOMA CITY        117 NW 9
# 3408  117 NW 9, OKLAHOMA CITY, OK 73102  OKLAHOMA CITY        117 NW 9
# 3424  117 NW 9, OKLAHOMA CITY, OK 73102  OKLAHOMA CITY        117 NW 9
#
#      Shipping State/Province Shipping Zip/Postal Code  details1  \
# 0                         OK                    73102   Inside
# 16                        OK                    73102   Inside
# 32                        OK                    73102   Inside
# 48                        OK                    73102   Inside
# 64                        OK                    73102   Inside
# 80                        OK                    73102   Inside
# 96                        OK                    73102  Outside
# 112                       OK                    73102  Outside
# 128                       OK                    73102  Outside
# 144                       OK                    73102  Outside
# 160                       OK                    73102   Inside
# 176                       OK                    73102   Inside
# 192                       OK                    73102   Inside
# 208                       OK                    73102   Inside
# 240                       OK                    73102     Unit
# 384                       OK                    73102   Inside
# 400                       OK                    73102  Outside
# 784                       OK                    73102   Inside
# 992                       OK                    73102     Unit
# 1024                      OK                    73102     Unit
# 1040                      OK                    73102     Unit
# 1056                      OK                    73102     Unit
# 1072                      OK                    73102     Unit
# 1136                      OK                    73102     Unit
# 1664                      OK                    73102     Unit
# 1824                      OK                    73102     Unit
# 1840                      OK                    73102     Unit
# 1920                      OK                    73102     Unit
# 2352                      OK                    73102     Unit
# 2384                      OK                    73102     Unit
# 2416                      OK                    73102     Unit
# 3264                      OK                    73102     Unit
# 3408                      OK                    73102     Unit
# 3424                      OK                    73102     Unit
#
#                                    details2  \
# 0                                Exit Sign
# 16                                Handrail
# 32               Floor Covering and Finish
# 48                                 Ceiling
# 64               Floor Covering and Finish
# 80               Floor Covering and Finish
# 96                     Lighting - Exterior
# 112                               Handrail
# 128                    Lighting - Exterior
# 144                          Roof Assembly
# 160                    Door - Fire Labeled
# 176                            Sharp Edges
# 192                    Lighting - Interior
# 208         Electrical - Outlet and Switch
# 240                           Refrigerator
# 384                                Ceiling
# 400    Wall Covering and Finish - Exterior
# 784                   Lighting - Auxiliary
# 992                           Refrigerator
# 1024                          Door - Entry
# 1040                     Cooking Appliance
# 1056                               Ceiling
# 1072                    Bathtub and Shower
# 1136                           Infestation
# 1664                           Infestation
# 1824                           Infestation
# 1840                           Infestation
# 1920                                  Leak
# 2352   Wall Covering and Finish - Interior
# 2384                           Infestation
# 2416                           Infestation
# 3264                          Refrigerator
# 3408                     Cooking Appliance
# 3424                          Refrigerator
#
#                                                details3  \
# 0      Lighted exit sign does not illuminate or ther...
# 16                              Handrail is not secure
# 32     Floor covering is curling, buckling, bulging,...
# 48                     Ceiling has an unstable surface
# 64                          Floor substrate is exposed
# 80     Floor covering is curling, buckling, bulging,...
# 96     A permanently installed light fixture is miss...
# 112                             Handrail is not secure
# 128    A permanently installed light fixture is miss...
# 144    Gutter component is damaged, missing, or unfi...
# 160    Fire labeled door does not close and latch or...
# 176    A sharp edge that can result in a cut or punc...
# 192    A permanently installed light fixture is not ...
# 208                        Outlet or switch is damaged
# 240    Refrigerator component is damaged such that i...
# 384                                 Ceiling has a hole
# 400    Exterior wall has a hole of any size that pen...
# 784    Auxiliary lighting component is damaged or mi...
# 992    Refrigerator is inoperable such that it may b...
# 1024   Entry door component is damaged, inoperable, ...
# 1040   Cooking range, cooktop, or oven is not produc...
# 1056                   Ceiling has an unstable surface
# 1072   Only 1 bathtub or shower is present and it is...
# 1136                           Evidence of cockroaches
# 1664                           Evidence of cockroaches
# 1824                           Evidence of cockroaches
# 1840                               Evidence of bedbugs
# 1920                                    Plumbing leaks
# 2352   Interior wall has a hole of any size that pen...
# 2384                           Evidence of cockroaches
# 2416                               Evidence of bedbugs
# 3264   Refrigerator is inoperable such that it may b...
# 3408   Cooking range, cooktop, or oven is not produc...
# 3424   Refrigerator is inoperable such that it may b...
#
#                                                details4
# 0                        Exit sign does not illuminate.
# 16     There is movement in the anchors of the handr...
# 32     Any portion of the floor covering is curling,...
# 48                      Ceiling has an unstable surface
# 64     10% or more of the floor substrate area is ex...
# 80     Any portion of the floor covering is curling,...
# 96     A permanently installed light fixture is dama...
# 112    There is movement in the anchors of the handrail
# 128    A permanently installed light fixture is dama...
# 144    Gutter component is damaged (i.e., visibly de...
# 160    If self-closing mechanism is present, fire la...
# 176    A sharp edge that can result in a cut or punc...
# 192    A permanently installed light fixture is not ...
# 208    Any portion of a visually accessible (i.e., c...
# 240    Refrigerator component is damaged (i.e., visi...
# 384    A hole is present that is 2 inches or greater...
# 400    A hole of any size that penetrates through to...
# 784    Auxiliary lighting component is missing (i.e....
# 992    Refrigerator is inoperable (i.e., overall sys...
# 1024   Entry door component is damaged (i.e., visibl...
# 1040   50% of the burners on the cooking range or co...
# 1056                    Ceiling has an unstable surface
# 1072   Only 1 bathtub or shower is present within th...
# 1136   Presence of dead or live cockroaches, shed sk...
# 1664   Presence of dead or live cockroaches, shed sk...
# 1824   Presence of dead or live cockroaches, shed sk...
# 1840                       Evidence of bedbugs is found
# 1920   Failure of a plumbing system that allows for ...
# 2352   A hole of any size penetrates to the adjoinin...
# 2384   Presence of dead or live cockroaches, shed sk...
# 2416                       Evidence of bedbugs is found
# 3264   Refrigerator is inoperable (i.e., overall sys...
# 3408                    The oven is not producing heat.
# 3424   Refrigerator is inoperable (i.e., overall sys...

# %% [markdown]
# # Time breakdown

# %% [markdown]
# Look at times when deficiencies were identified.

# %%
# Cast to datetime
nspire['Defect Recorded Date'] = pd.to_datetime(nspire['Defect Recorded Date'])

# Create new columns for year and month
nspire['Defect Recorded Year'] = nspire['Defect Recorded Date'].dt.year
nspire['Defect Recorded Month'] = nspire['Defect Recorded Date'].dt.month

# %%
nspire.groupby(['Defect Recorded Year']).nunique()['Inspection ID']
# Out:
# Defect Recorded Year
# 2021.0      21
# 2022.0    2353
# 2023.0     548
# Name: Inspection ID, dtype: int64

# %% [markdown]
# # How many deficiencies are fire related?

# %%
fire_standards = [
    "Carbon Monoxide Alarm",
    "Leak",
    "Chimney",
    "Door - Fire Labeled",
    "Electrical - Outlet and Switch",
    "Electrical - Conductor",
    "Electrical - Service Panel",
    "Electrical - GFCI or AFCI Outlet or Breaker",
    "Fire Escape",
    "Fire Extinguisher",
    "Flammable and Combustible Item",
    "Smoke Alarm",
    "Heating, Ventilation, and Air Conditioning (HVAC)",
    "Kitchen Ventilation",
    "Structural System"
]

# %%
data = nspire.groupby('NSPIRE Standards').size().sort_values()

# Extract labels and values
labels = data.index.tolist()
values = data.values.tolist()

# Determine the color of each bar
colors = ['skyblue' if label.strip() not in fire_standards else 'red' for label in labels]

# Create the bar plot
plt.figure(figsize=(10, 15))
plt.barh(labels, values, color=colors)
plt.xlabel('Counts')
plt.title('NSPIRE Standards')
plt.show()

# %% [markdown]
# # Characteristics of fire-related deficiencies

# %%
nspire_notna = nspire[nspire['NSPIRE Standards'].notna()]

# %%
fire_related = nspire_notna[nspire_notna['NSPIRE Standards'].isin(fire_standards)]

# %%
for standard in fire_related['NSPIRE Standards'].unique():
    details3_counts = fire_related[fire_related['NSPIRE Standards'] == standard]['details3'].value_counts()
    
    # Print the standard in bold
    display(standard)
    
    # Print each unique 'details3' with its count as a bullet point
    for detail, count in details3_counts.items():
        display(Markdown(f"- {detail}: {count} occurrences"))
        
    # Add a line break for readability
    display(Markdown("---"))
# Out:
# **Leak**
# -  Plumbing leaks : 998 occurrences
# -  Environmental water intrusion : 124 occurrences
# -  Leak in sewage system : 41 occurrences
# -  Cap to the cleanout is detached or missing : 28 occurrences
# -  Cleanout cap or riser has penetrative hole or crack : 16 occurrences
# -  Blocked sewage system : 8 occurrences
# -  Natural gas, propane, or oil leak : 7 occurrences
# ---
# **Smoke Alarm**
# -  Smoke alarm is not installed where required : 3466 occurrences
# -  Smoke alarm does not produce an audio or visual alarm when tested : 1352 occurrences
# ---
# **Flammable and Combustible Item**
# -  Improperly stored flammable or combustible item on or near an ignition source : 421 occurrences
# ---
# **Electrical - GFCI or AFCI Outlet or Breaker**
# -  GFCI outlet or GFCI breaker is not visibly damaged and the test or reset button is inoperable : 2617 occurrences
# -  AFCI outlet or AFCI breaker is not visibly damaged and the test or reset button is inoperable : 156 occurrences
# ---
# **Electrical - Outlet and Switch**
# -  An unprotected outlet is present within six feet of a water source : 4209 occurrences
# -  Outlet or switch is damaged : 1139 occurrences
# -  Testing indicates a three-pronged outlet is not properly wired or grounded : 780 occurrences
# -  Outlet does not have visible damage and testing indicates it is not energized : 311 occurrences
# ---
# **Carbon Monoxide Alarm**
# -  Carbon monoxide detector is missing, not installed, or not installed in a proper location : 3105 occurrences
# -  Carbon monoxide detector does not produce audio or visual alarm when tested : 304 occurrences
# -  Carbon monoxide detector is obstructed : 11 occurrences
# ---
# **Electrical - Conductor**
# -  Exposed electrical conductor : 2080 occurrences
# ---
# **Fire Extinguisher**
# -  Fire extinguisher service tag is missing, illegible, or expired : 508 occurrences
# -  Fire extinguisher pressure gauge reads over or under-charged : 120 occurrences
# -  Fire extinguisher is missing : 30 occurrences
# ---
# **Electrical - Service Panel**
# -  Electrical service panel is not reasonably accessible : 342 occurrences
# -  The overcurrent protection device is damaged : 60 occurrences
# -  The overcurrent protection device is contaminated : 32 occurrences
# ---
# **Door - Fire Labeled**
# -  Fire labeled door does not close and latch or self-close and latch : 1444 occurrences
# -  Fire labeled door assembly has a hole of any size or is damaged such that its integrity may be compromised : 151 occurrences
# -  Fire labeled door seal or gasket is damaged or missing : 71 occurrences
# -  Fire labeled door does not open : 25 occurrences
# ---
# **Kitchen Ventilation**
# -  Exhaust system does not respond to the control switch : 221 occurrences
# -  Exhaust system component is damaged or missing : 134 occurrences
# -  Exhaust system has restricted airflow : 104 occurrences
# ---
# **Heating, Ventilation, and Air Conditioning (HVAC)**
# -  Air conditioning system or device is not operational : 89 occurrences
# -  Heating system or device fueled by combustion has a misaligned, disconnected, improperly connected, damaged, blocked, or missing exhaust vent : 66 occurrences
# -  Outside temperature is below 68 degrees Fahrenheit and the resident is unable to maintain a minimum temperature of 68 degrees Fahrenheit through a safe heating source : 35 occurrences
# -  Outside temperature is 68 degrees Fahrenheit or above and the resident is unable to maintain a minimum temperature of 68 degrees Fahrenheit through a safe heating source : 25 occurrences
# -  Combustion chamber cover or gas shutoff valve is missing from a combustion-fueled heating appliance : 3 occurrences
# ---
# **Structural System**
# -  Structural system exhibits signs of serious failure : 93 occurrences
# ---
# **Chimney**
# -  A visually accessible chimney, flue, or firebox connected to a fireplace or wood-burning appliance is incomplete or damaged such that it may not safely contain fire and convey smoke and combustion gases to the exterior : 6 occurrences
# -  Chimney exhibits signs of structural failure : 1 occurrences
# ---
# **Fire Escape**
# -  Fire escape component is damaged or missing : 1 occurrences
# ---

# %%
grouped = fire_related.groupby(['NSPIRE Standards', 'details1']).size()

df = grouped.reset_index()
df.columns = ['NSPIRE Standards', 'NSPIRE Health & Safety', 'count']

# Pivot your DataFrame
df_pivot = df.pivot(index='NSPIRE Standards', columns='NSPIRE Health & Safety', values='count')

colors = {'Inside ': 'Green', 'Unit ': 'Blue', 'Outside ': 'Orange'}

# Create a list of colors for each column
column_colors = [colors[col] for col in reversed(df_pivot.columns)]

# Reorder the DataFrame columns for stacking and bars for total count
df_pivot = df_pivot[reversed(df_pivot.columns)]
df_pivot = df_pivot.reindex(df_pivot.sum(axis=1).sort_values(ascending=False).index)

# Plotting
df_pivot.plot(kind='bar', stacked=True, color=column_colors, figsize=(15,10))
plt.title('Fire-related NSPIRE Standards and Health & Safety issues')
plt.xlabel('NSPIRE Standards')
plt.ylabel('Count')
plt.show()

# %%
grouped = fire_related.groupby(['NSPIRE Standards', 'NSPIRE Health & Safety']).size()

df = grouped.reset_index()
df.columns = ['NSPIRE Standards', 'NSPIRE Health & Safety', 'count']

# Pivot your DataFrame
df_pivot = df.pivot(index='NSPIRE Standards', columns='NSPIRE Health & Safety', values='count')

# Define the color map with more contrast and reverse the order for stacking
colors = {'Standard': '#FFCCCC', 'Severe Non-Life-Threatening': '#FF6666', 'Life-Threatening': '#CC0000'}

# Create a list of colors for each column
column_colors = [colors[col] for col in reversed(df_pivot.columns)]

# Reorder the DataFrame columns for stacking and bars for total count
df_pivot = df_pivot[reversed(df_pivot.columns)]
df_pivot = df_pivot.reindex(df_pivot.sum(axis=1).sort_values(ascending=False).index)

# Plotting
df_pivot.plot(kind='bar', stacked=True, color=column_colors, figsize=(15,10))
plt.title('Fire-related NSPIRE Standards and Health & Safety issues')
plt.xlabel('NSPIRE Standards')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Fire related deficiencies by location

# %% [markdown]
# ### Alarms as percent of all deficiencies by state

# %%
nspire.groupby(by='Shipping State/Province').size().sort_values()
# Out:
# Shipping State/Province
# NM       4
# ON      10
# ND      33
# OR      60
# MT      60
# IA     117
# SD     155
# UT     172
# MN     192
# VT     290
# NV     312
# AR     320
# AZ     396
# ME     409
# WV     456
# DE     478
# KS     480
# WA     583
# NE     662
# WI     939
# IN    1011
# CO    1112
# OK    1217
# NH    1258
# RI    1424
# GA    1520
# MD    1537
# SC    1825
# TX    1856
# OH    2002
# TN    2038
# KY    2108
# VA    2122
# IL    2317
# MO    2341
# LA    2466
# MS    2472
# NJ    2613
# MI    2987
# NC    3121
# FL    3321
# CT    3357
# MA    3445
# NY    4577
# PA    5112
# AL    5182
# CA    6758
# dtype: int64

# %%
alarms = nspire[
    (nspire['NSPIRE Standards'] == 'Smoke Alarm') |
    (nspire['NSPIRE Standards'] == 'Carbon Monoxide Alarm')
]

# Select relevant data and group by 'Shipping State/Province' and 'NSPIRE Standards'
grouped_alarms = alarms.groupby(by=['Shipping State/Province', 'NSPIRE Standards']).size().reset_index()
grouped_alarms.columns = ['Shipping State/Province', 'NSPIRE Standards', 'count']

# Pivot the data
pivot_alarms = grouped_alarms.pivot(index='Shipping State/Province', columns='NSPIRE Standards', values='count')

# Fill NaN values with 0
pivot_alarms = pivot_alarms.fillna(0)

# Add a total column and sort by it
pivot_alarms['total'] = pivot_alarms.sum(axis=1)
pivot_alarms = pivot_alarms.sort_values('total', ascending=False)

# Remove the total column before plotting
del pivot_alarms['total']

# Calculate total alarm deficiencies for each state
total_alarm_deficiencies = pivot_alarms.sum(axis=1)

total_deficiencies = nspire.groupby(by='Shipping State/Province').size()

# Calculate proportion of alarm deficiencies to total deficiencies for each state
proportion_alarm_deficiencies = total_alarm_deficiencies / total_deficiencies

# Calculate the proportion of alarm deficiencies to total deficiencies
pivot_alarms_proportion = pivot_alarms.div(total_deficiencies, axis=0)

# Remove any NaN values (might occur if a state has no deficiencies at all)
pivot_alarms_proportion = pivot_alarms_proportion.fillna(0)

# Sort states by proportion of alarm deficiencies
pivot_alarms_proportion = pivot_alarms_proportion.loc[proportion_alarm_deficiencies.sort_values(ascending=False).index]

# Plot the data
pivot_alarms_proportion.plot(kind='bar', stacked=True, figsize=(15,10), cmap='tab10')
plt.title('Proportion of alarm deficiencies by State')
plt.xlabel('Shipping State/Province')
plt.ylabel('Proportion')
plt.show()

# %% [markdown]
# ### Alarms as percent of all deciciencies by city

# %%
alarms = nspire[
    (nspire['NSPIRE Standards'] == 'Smoke Alarm') |
    (nspire['NSPIRE Standards'] == 'Carbon Monoxide Alarm')
]

# Select relevant data and group by 'Shipping City', 'Shipping State/Province', and 'NSPIRE Standards'
grouped_alarms = alarms.groupby(by=['Shipping City', 'Shipping State/Province', 'NSPIRE Standards']).size().reset_index()
grouped_alarms.columns = ['Shipping City', 'Shipping State/Province', 'NSPIRE Standards', 'count']

# Create a new 'City, State' column for clearer labeling in the plot
grouped_alarms['City, State'] = grouped_alarms['Shipping City'] + ', ' + grouped_alarms['Shipping State/Province']

# Pivot the data
pivot_alarms = grouped_alarms.pivot(index='City, State', columns='NSPIRE Standards', values='count')

# Fill NaN values with 0
pivot_alarms = pivot_alarms.fillna(0)

# Add a total column and sort by it
pivot_alarms['total'] = pivot_alarms.sum(axis=1)
pivot_alarms = pivot_alarms.sort_values('total', ascending=False)

# Remove the total column before plotting
del pivot_alarms['total']

# Calculate total alarm deficiencies for each city
total_alarm_deficiencies = pivot_alarms.sum(axis=1)

total_deficiencies = nspire.groupby(by=['Shipping City', 'Shipping State/Province']).size()
total_deficiencies.index = total_deficiencies.index.map(', '.join)

# Calculate proportion of alarm deficiencies to total deficiencies for each city
proportion_alarm_deficiencies = total_alarm_deficiencies / total_deficiencies

# Remove cities where the proportion is zero
proportion_alarm_deficiencies = proportion_alarm_deficiencies[proportion_alarm_deficiencies > 0]

# Calculate the proportion of alarm deficiencies to total deficiencies
pivot_alarms_proportion = pivot_alarms.div(total_deficiencies, axis=0)

# Remove any NaN values (might occur if a city has no deficiencies at all)
pivot_alarms_proportion = pivot_alarms_proportion.fillna(0)

# Sort cities by proportion of alarm deficiencies
pivot_alarms_proportion = pivot_alarms_proportion.loc[proportion_alarm_deficiencies.sort_values(ascending=False).index]

top_30_cities = pivot_alarms_proportion.iloc[:50]
bottom_30_cities = pivot_alarms_proportion.iloc[-50:]

top_30_cities.plot(kind='bar', stacked=True, figsize=(15,10), cmap='tab10')
plt.title('Proportion of alarm deficiencies by City (Top 50)')
plt.xlabel('City, State')
plt.ylabel('Proportion')
plt.show()

bottom_30_cities.plot(kind='bar', stacked=True, figsize=(15,10), cmap='tab10')
plt.title('Proportion of alarm deficiencies by City (Bottom 50)')
plt.xlabel('City, State')
plt.ylabel('Proportion')
plt.show()

# %% [markdown]
# ### Electrical issues as percent of all deficiencies by state

# %%
electric = nspire[
    (nspire['NSPIRE Standards'] == "Electrical - Outlet and Switch") |
    (nspire['NSPIRE Standards'] == "Electrical - Conductor") |
    (nspire['NSPIRE Standards'] == "Electrical - Service Panel") |
    (nspire['NSPIRE Standards'] == "Electrical - GFCI or AFCI Outlet or Breaker")
]

# Select relevant data and group by 'Shipping State/Province' and 'NSPIRE Standards'
grouped_electric = electric.groupby(by=['Shipping State/Province', 'NSPIRE Standards']).size().reset_index()
grouped_electric.columns = ['Shipping State/Province', 'NSPIRE Standards', 'count']

# Pivot the data
pivot_electric = grouped_electric.pivot(index='Shipping State/Province', columns='NSPIRE Standards', values='count')

# Fill NaN values with 0
pivot_electric = pivot_electric.fillna(0)

# Add a total column and sort by it
pivot_electric['total'] = pivot_electric.sum(axis=1)
pivot_electric = pivot_electric.sort_values('total', ascending=False)

# Remove the total column before plotting
del pivot_electric['total']

# Calculate total electric deficiencies for each state
total_electric_deficiencies = pivot_electric.sum(axis=1)

total_deficiencies = nspire.groupby(by='Shipping State/Province').size()

# Calculate proportion of electric deficiencies to total deficiencies for each state
proportion_electric_deficiencies = total_electric_deficiencies / total_deficiencies

# Calculate the proportion of electric deficiencies to total deficiencies
pivot_electric_proportion = pivot_electric.div(total_deficiencies, axis=0)

# Remove any NaN values (might occur if a state has no deficiencies at all)
pivot_electric_proportion = pivot_electric_proportion.fillna(0)

# Sort states by proportion of electric deficiencies
pivot_electric_proportion = pivot_electric_proportion.loc[proportion_electric_deficiencies.sort_values(ascending=False).index]

# Plot the data
pivot_electric_proportion.plot(kind='bar', stacked=True, figsize=(15,10), cmap='tab10')
plt.title('Proportion of electrical deficiencies by State')
plt.xlabel('Shipping State/Province')
plt.ylabel('Proportion')
plt.show()

# %% [markdown]
# # Export

# %%
nspire.to_csv('../data/processed/nspire_partial_clean.csv', index=False, sep=',')
