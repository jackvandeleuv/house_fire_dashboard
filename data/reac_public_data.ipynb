# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import folium

# %% [markdown]
# # Explore public HUD REAC data in Philadelphia

# %% [markdown]
# Author: Jack Vandeleuv
#
# Data files:
# * [Public Housing Physical Inspection Scores (2016-2021)](https://www.huduser.gov/portal/datasets/pis.html#2021_data-collapse)
# * [Multifamily Physical Inspection Scores (2016-2021)](https://www.huduser.gov/portal/datasets/pis.html#2021_data-collapse)

# %% [markdown]
# This notebook will explore the publicly released scores from the U.S. Department of Housing and Urban Development's Real Estate Assessment Center (HUD REAC). These scores are derived from physical inspections on HUD properties.

# %% [markdown]
# # Loading and cleaning

# %% [markdown]
# Place the data files in the data directory and load into pandas.

# %%
WORKING_DIR = '../data/'
MULTIFAMILY_FILES = [
    'multifamily_physical_inspection_scores_0321.xlsx',
    'multifamily_physical_inspection_scores_0620.xlsx',
    'multifamily-physical-inspection-scores-2016.xlsx',
    'multifamily-physical-inspection-scores-2018.xlsx',
    'multifamily-physical-inspection-scores-2019.xlsx'
]

PUBLIC_HOUSING_FILES = [
    'public_housing_physical_inspection_scores_0321.xlsx',
    'public_housing_physical_inspection_scores_0620.xlsx',
    'public-housing-physical-inspection-scores-2016.xlsx',
    'public-housing-physical-inspection-scores-2018.xlsx',
    'public-housing-physical-inspection-scores-2019.xlsx'
]

# %%
multi_dfs = []
public_dfs = []

for i, public_file in enumerate(PUBLIC_HOUSING_FILES):
    public_dfs.append(pd.read_excel(WORKING_DIR + public_file))
    multi_dfs.append(pd.read_excel(WORKING_DIR + MULTIFAMILY_FILES[i]))

multi = pd.concat(multi_dfs, axis=0)
public = pd.concat(public_dfs, axis=0)

# %%
multi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 137649 entries, 0 to 27877
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   INSPECTION_ID     137649 non-null  int64
#  1   PROPERTY_ID       137649 non-null  int64
#  2   PROPERTY_NAME     137649 non-null  object
#  3   ADDRESS           136278 non-null  object
#  4   CITY              137649 non-null  object
#  5   CBSA_NAME         126260 non-null  object
#  6   CBSA_CODE         137585 non-null  float64
#  7   COUNTY_NAME       137597 non-null  object
#  8   COUNTY_CODE       137599 non-null  float64
#  9   STATE_NAME        82016 non-null   object
#  10  STATE_CODE        137649 non-null  object
#  11  ZIPCODE           55335 non-null   float64
#  12  LATITUDE          137599 non-null  float64
#  13  LONGITUDE         137599 non-null  float64
#  14  LOCATION_QUALITY  137599 non-null  object
#  15  INSPECTION_SCORE  137649 non-null  int64
#  16  INSPECTION_DATE   137649 non-null  object
#  17  ZIP               82272 non-null   float64
#  18  FIPS_STATE_CODE   55633 non-null   float64
# dtypes: float64(7), int64(3), object(9)
# memory usage: 21.0+ MB

# %%
public.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34125 entries, 0 to 6782
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   INSPECTION_ID     34125 non-null  int64
#  1   DEVELOPMENT_ID    34125 non-null  object
#  2   DEVELOPMENT_NAME  34125 non-null  object
#  3   ADDRESS           13162 non-null  object
#  4   CITY              34125 non-null  object
#  5   CBSA_NAME         29207 non-null  object
#  6   CBSA_CODE         34108 non-null  float64
#  7   COUNTY_NAME       34108 non-null  object
#  8   COUNTY_CODE       34108 non-null  float64
#  9   STATE_NAME        20419 non-null  object
#  10  STATE_CODE        34117 non-null  object
#  11  ZIPCODE           13162 non-null  float64
#  12  LATITUDE          34108 non-null  float64
#  13  LONGITUDE         34108 non-null  float64
#  14  LOCATION_QUALITY  34116 non-null  object
#  15  PHA_CODE          34125 non-null  object
#  16  PHA_NAME          34125 non-null  object
#  17  INSPECTION_SCORE  34125 non-null  int64
#  18  INSPECTION_DATE   34125 non-null  object
#  19  ADDRESS           20479 non-null  object
#  20  ZIP               20954 non-null  float64
#  21  FIPS_STATE_CODE   13706 non-null  float64
# dtypes: float64(7), int64(2), object(13)
# memory usage: 6.0+ MB

# %% [markdown]
# It looks like we have multiple zipcode formats between years. We'll also drop FIPS_STATE_CODE, which we don't need for this analysis.

# %%
multi = multi.drop(['FIPS_STATE_CODE'], axis=1)
public = public.drop(['FIPS_STATE_CODE'], axis=1)

# %% [markdown]
# We'll also convert INSPECTION_DATE to a standard datetime format.

# %%
public['INSPECTION_DATE'] = pd.to_datetime(public['INSPECTION_DATE'], infer_datetime_format=True)
multi['INSPECTION_DATE'] = pd.to_datetime(multi['INSPECTION_DATE'], infer_datetime_format=True)

# %%
print(public.INSPECTION_DATE.dtype, multi.INSPECTION_DATE.dtype)
# Out:
# datetime64[ns] datetime64[ns]

# %% [markdown]
# Let's also get rid of redundant inspections. We'll define these as inspection that share the same INSPECTION_ID.

# %%
multi = multi[~multi.INSPECTION_ID.duplicated()]
public = public[~public.INSPECTION_ID.duplicated()]

# %% [markdown]
# For this analysis, we're interested in Philadelphia specifically, so we'll limit ourselves to those inspections.

# %%
public = public[public.CITY == 'Philadelphia']
multi = multi[multi.CITY == 'Philadelphia']

# %%
public.sample(3)
# Out:
#       INSPECTION_ID DEVELOPMENT_ID     DEVELOPMENT_NAME            ADDRESS  \
# 11           523879    PA002000132        Suffolk Manor  1416 Clearview St
# 4808         625664    PA002000147  Cambridge Phase III                NaN
# 3813         547665    PA002000013          WILSON PARK                NaN
#
#               CITY                                          CBSA_NAME  \
# 11    Philadelphia  Philadelphia-Camden-Wilmington, PA-NJ-DE-MD Me...
# 4808  Philadelphia  Philadelphia-Camden-Wilmington, PA-NJ-DE-MD Me...
# 3813  Philadelphia             Philadelphia, PA Metropolitan Division
#
#       CBSA_CODE   COUNTY_NAME  COUNTY_CODE STATE_NAME  ...  ZIPCODE  \
# 11      37980.0  Philadelphia        101.0         PA  ...  19141.0
# 4808    37980.0  Philadelphia        101.0        NaN  ...      NaN
# 3813    37964.0  Philadelphia        101.0         PA  ...      NaN
#
#        LATITUDE  LONGITUDE  LOCATION_QUALITY PHA_CODE  \
# 11    40.040464 -75.145217                 R    PA002
# 4808  39.966800 -75.154900                 B    PA002
# 3813  39.925450 -75.189028                 R    PA002
#
#                             PHA_NAME INSPECTION_SCORE     INSPECTION_DATE  \
# 11    Philadelphia Housing Authority               98 2014-06-03 09:04:17
# 4808  Philadelphia Housing Authority               77 2018-08-28 00:00:00
# 3813  Philadelphia Housing Authority               91 2015-05-28 00:00:00
#
#               ADDRESS       ZIP
# 11                 NaN      NaN
# 4808  905 N Marvine St  19123.0
# 3813   2508 Jackson St  19145.0
#
# [3 rows x 21 columns]

# %% [markdown]
# # Basic exploration

# %% [markdown]
# We'll pull the overall summary statistics for this dataset.

# %%
print(public.describe())
print(f'% with failing score: {len(public[public.INSPECTION_SCORE < 60]) / len(public): .2f}')
# Out:
#        INSPECTION_ID     CBSA_CODE  COUNTY_CODE       ZIPCODE    LATITUDE  \
# count     227.000000    227.000000        227.0     78.000000  227.000000
# mean   593718.145374  37971.400881        101.0  19129.320513   39.979040
# std     43194.941983      7.995164          0.0     12.848259    0.031648
# min    523098.000000  37964.000000        101.0  19104.000000   39.917289
# 25%    567871.000000  37964.000000        101.0  19121.000000   39.964239
# 50%    589742.000000  37964.000000        101.0  19129.500000   39.973101
# 75%    625671.500000  37980.000000        101.0  19140.500000   39.994740
# max    667178.000000  37980.000000        101.0  19151.000000   40.049387
#
#         LONGITUDE  INSPECTION_SCORE           ZIP
# count  227.000000        227.000000    149.000000
# mean   -75.174367         73.986784  19130.013423
# std      0.036523         18.412789     12.761315
# min    -75.244380         22.000000  19104.000000
# 25%    -75.197136         62.500000  19121.000000
# 50%    -75.174270         77.000000  19130.000000
# 75%    -75.153343         90.000000  19141.000000
# max    -75.024208         99.000000  19151.000000
# % with failing score:  0.22

# %%
print(multi.describe())
print(f'% with failing score: {len(multi[multi.INSPECTION_SCORE < 60]) / len(multi): .2f}')
# Out:
#        INSPECTION_ID   PROPERTY_ID     CBSA_CODE  COUNTY_CODE       ZIPCODE  \
# count     346.000000  3.460000e+02    346.000000   346.000000    163.000000
# mean   581375.274566  8.000861e+08  38778.231214   100.491329  19343.030675
# std     47026.695875  9.287763e+04   6696.271255     5.201581   2277.255681
# min    500931.000000  8.000121e+08  37964.000000    45.000000  13673.000000
# 25%    543138.750000  8.000186e+08  37964.000000   101.000000  19116.000000
# 50%    584890.000000  8.000189e+08  37980.000000   101.000000  19131.000000
# 75%    621644.500000  8.002148e+08  37980.000000   101.000000  19141.000000
# max    672303.000000  8.002452e+08  99999.000000   101.000000  39350.000000
#
#          LATITUDE   LONGITUDE  INSPECTION_SCORE           ZIP
# count  346.000000  346.000000        346.000000    183.000000
# mean    39.944159  -75.325541         85.072254  19289.530055
# std      0.869622    1.494309         13.909771   2189.680063
# min     32.754848  -89.111520         23.000000  13673.000000
# 25%     39.957123  -75.204718         79.000000  19119.000000
# 50%     39.979567  -75.163390         90.000000  19130.000000
# 75%     40.025196  -75.141594         95.000000  19140.000000
# max     44.150556  -75.011480        100.000000  39350.000000
# % with failing score:  0.06

# %% [markdown]
# We have 78 public housing inspections and 163 multifamily inspections. For public, 22% on inspections assigned a failing grade, whereas only 6% did for multifamily.

# %% [markdown]
# Now let's get inspection count by year.

# %%
multi_counts = multi.INSPECTION_DATE.dt \
                                    .year \
                                    .value_counts() \
                                    .sort_index()
print(multi_counts)
print(multi_counts.mean())
# Out:
# 2013    27
# 2014    53
# 2015    47
# 2016    47
# 2017    41
# 2018    69
# 2019    46
# 2020    16
# Name: INSPECTION_DATE, dtype: int64
# 43.25

# %%
public_counts = public.INSPECTION_DATE.dt \
                                        .year \
                                        .value_counts() \
                                        .sort_index()
print(public_counts)
print(public_counts.mean())
# Out:
# 2014    29
# 2015    27
# 2016    25
# 2017    57
# 2018    50
# 2019    30
# 2020     9
# Name: INSPECTION_DATE, dtype: int64
# 32.42857142857143

# %% [markdown]
# On average, there are 43 and 32 inspection for multifamily and public housing respectively every year.

# %% [markdown]
# # Quick exploratory mapping

# %% [markdown]
# Here is the location of all the inspection on a map. We'll color the points based on inspection score.

# %%
def inspection_score_color(score):
    if score >= 80:
        return 'green'
    elif score >= 60:
        return 'orange'
    else:
        return 'red'

# %%
philly_map = folium.Map(location=[39.9526, -75.1652], zoom_start=13)

for index, row in public.iterrows():
    folium.Marker(
        location=[row['LATITUDE'], row['LONGITUDE']],
        popup=f"{row['DEVELOPMENT_NAME']} - Score: {row['INSPECTION_SCORE']} - Coord: {row['LATITUDE']}, {row['LONGITUDE']}",
        icon=folium.Icon(color=inspection_score_color(row['INSPECTION_SCORE']), icon='info-sign')
    ).add_to(philly_map)

for index, row in multi.iterrows():
    folium.Marker(
        location=[row['LATITUDE'], row['LONGITUDE']],
        popup=f"{row['PROPERTY_NAME']} - Score: {row['INSPECTION_SCORE']} - Coord: {row['LATITUDE']}, {row['LONGITUDE']}",
        icon=folium.Icon(color=inspection_score_color(row['INSPECTION_SCORE']), icon='info-sign')
    ).add_to(philly_map)

philly_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_40072fd76532d71b4d67ef2de60df2c2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_40072fd76532d71b4d67ef2de60df2c2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_40072fd76532d71b4d67ef2de60df2c2 = L.map(
#                 &quot;map_40072fd76532d71b4d67ef2de60df2c2&quot;,
#                 {
#                     center: [39.9526, -75.1652],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3ece129118281a6c9b59175b6b9be235 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_40072fd76532d71b4d67ef2de60df2c2);
#
#
#             var marker_3268ffe5b6c86d49b39eef8f63aea1a7 = L.marker(
#                 [39.969513, -75.153273],
#                 {}
#             ).addTo(map_40072fd76532d71b4d67ef2de60df2c2);
#
#
#             var icon_ba9b36ab700240132b73c26bb6ba676f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3268ffe5b6c86d49b39eef8f63aea1a7.setIcon(icon_ba9b36ab700240132b73c26bb6ba676f);
#
#
#         var popup_86668a50de74c025e85a9a6d910860a1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b2c50feb3fc2a4cd91b73d50eece573e = $(`&lt;div id=&quot;html_b2c50feb3fc2a4cd91b73d50eece573e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CAMBRIDGE PHASE II - Score: 97 - Coord: 39.969513, -75.153273&lt;/div&gt;`)[0];
#                 popup_86668a50de74c025e85a9a6d910860a1.setContent(html_b2c50feb3fc2a4cd91b73d50eece573e);
#
#
#
#         marker_3268ffe5b6c86d49b39eef8f63aea1a7.bindPopup(popup_86668a50de74c025e85a9a6d910860a1)
#         ;
#
#
#
#
#             var marker_48a17dfa66e81902c09d46afb71cc9b2 = L.marker(
#                 [40.040464, -75.145217],
#                 {}
#             ).addTo(map_40072fd76532d71b4d67ef2de60df2c2);
#
#
#             var icon_2d3f2b6a90b6c8111c9fbaf2a6339573 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_48a17dfa66e81902c09d46afb71cc9b2.setIcon(icon_2d3f2b6a90b6c8111c9fbaf2a6339573);
#
#
#         var popup_3e8b99eac738f8cd5a12c0922e2fd4f0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8baf9f94d1a7402f0d2747dabd7dbca7 = $(`&lt;div id=&quot;html_8baf9f94d1a7402f0d2747dabd7dbca7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Suffolk Manor - Score: 98 - Coord: 40.040464, -75.145217&lt;/div&gt;`)[0];
#                 popup_3e8b99eac738f8cd5a12c0922e2fd4f0.setContent(html_8baf9f94d1a7402f0d2747dabd7dbca7);
#
#
#
#         marker_48a17dfa66e81902c09d46afb71cc9b2.bindPopup(popup_3e8b99eac738f8cd5a12c0922e2fd4f0)
#         ;
#
#
#
#
#             var marker_23a56aa1655dbb4468a996a4a5aed558 = L.marker(
#                 [39.995314, -75.188564],
#                 {}
#             ).addTo(map_40072fd76532d71b4d67ef2de60df2c2);
#
#
#             var icon_1ce4d57993b83b1de46d6a63d60200a7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_23a56aa1655dbb4468a996a4a5aed558.setIcon(icon_1ce4d57993b83b1de46d6a63d60200a7);
#
#
#         var popup_cc16459057eccdaba45762cb943a662b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_deba338d29e29c36868b7b4a511da407 = $(`&lt;div id=&quot;html_deba338d29e29c36868b7b4a511da407&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CECIL B MOORE HOMES - Score: 96 - Coord: 39.995314, -75.188564&lt;/div&gt;`)[0];
#                 popup_cc16459057eccdaba45762cb943a662b.setContent(html_deba338d29e29c36868b7b4a511da407);
#
#
#
#         marker_23a56aa1655dbb4468a996a4a5aed558.bindPopup(popup_cc16459057eccdaba45762cb943a662b)
#         ;
#
#
#
#
#             var marker_e78022513465f52c901a335638a614c1 = L.marker(
#                 [39.964314, -75.206995],
#                 {}
#             ).addTo(map_40072fd76532d71b4d67ef2de60df2c2);
#
#
#             var icon_d5d750b6

# %% [markdown]
# The 2022 Philadelphia fire in a HUD assisted property occurred at North 23rd Street and Ogden Street.
#
# The nearest REAC inspection in our dataset is across South College Avenue. The inspection was called 'SCATTERED SITES', which received a failing score of 46. [39.974478, -75.177185]
#
# The next closest was COLLEGEVIEW HOMES, which received a low score of 69. [39.975961, -75.180237]

# %%
pd.set_option('display.max_columns', None)
public[public.DEVELOPMENT_NAME.str.contains('COLLEGEVIEW HOMES')].sort_values(by='INSPECTION_DATE')
# Out:
#       INSPECTION_ID DEVELOPMENT_ID   DEVELOPMENT_NAME          ADDRESS  \
# 6535         567891    PA002000065  COLLEGEVIEW HOMES              NaN
# 4340         589708    PA002000065  COLLEGEVIEW HOMES              NaN
# 4786         625634    PA002000065  COLLEGEVIEW HOMES              NaN
# 4512         651085    PA002000065  COLLEGEVIEW HOMES  1251 Marston Ct
#
#               CITY                                          CBSA_NAME  \
# 6535  Philadelphia             Philadelphia, PA Metropolitan Division
# 4340  Philadelphia                                   Philadelphia, PA
# 4786  Philadelphia  Philadelphia-Camden-Wilmington, PA-NJ-DE-MD Me...
# 4512  Philadelphia  Philadelphia-Camden-Wilmington, PA-NJ-DE-MD Me...
#
#       CBSA_CODE   COUNTY_NAME  COUNTY_CODE STATE_NAME STATE_CODE  ZIPCODE  \
# 6535    37964.0  Philadelphia        101.0         PA         42      NaN
# 4340    37964.0  Philadelphia        101.0        NaN         PA      NaN
# 4786    37980.0  Philadelphia        101.0        NaN         PA      NaN
# 4512    37980.0  Philadelphia        101.0         PA       42.0  19121.0
#
#        LATITUDE  LONGITUDE LOCATION_QUALITY PHA_CODE  \
# 6535  39.975961 -75.180237                R    PA002
# 4340  39.975961 -75.180237                R    PA002
# 4786  39.975961 -75.180237                R    PA002
# 4512  39.975961 -75.180237                R    PA002
#
#                             PHA_NAME  INSPECTION_SCORE     INSPECTION_DATE  \
# 6535  Philadelphia Housing Authority                72 2016-03-29 00:00:00
# 4340  Philadelphia Housing Authority                74 2017-08-02 00:00:00
# 4786  Philadelphia Housing Authority                69 2018-08-09 00:00:00
# 4512  Philadelphia Housing Authority                67 2019-08-12 09:17:17
#
#              ADDRESS       ZIP
# 6535  1251 Marston Ct  19121.0
# 4340  1251 Marston Ct  19121.0
# 4786  1251 Marston Ct  19121.0
# 4512              NaN      NaN

# %%
public[public.LATITUDE == 39.974478].sort_values(by='INSPECTION_DATE')
# Out:
#       INSPECTION_ID DEVELOPMENT_ID DEVELOPMENT_NAME             ADDRESS  \
# 6556         567919    PA002000910  SCATTERED SITES                 NaN
# 4366         589741    PA002000910  SCATTERED SITES                 NaN
# 3298         631392    PA002000910  SCATTERED SITES  2501 N College Ave
#
#               CITY                                          CBSA_NAME  \
# 6556  Philadelphia             Philadelphia, PA Metropolitan Division
# 4366  Philadelphia                                   Philadelphia, PA
# 3298  Philadelphia  Philadelphia-Camden-Wilmington, PA-NJ-DE-MD Me...
#
#       CBSA_CODE   COUNTY_NAME  COUNTY_CODE STATE_NAME STATE_CODE  ZIPCODE  \
# 6556    37964.0  Philadelphia        101.0         PA         42      NaN
# 4366    37964.0  Philadelphia        101.0        NaN         PA      NaN
# 3298    37980.0  Philadelphia        101.0         PA       42.0  19121.0
#
#        LATITUDE  LONGITUDE LOCATION_QUALITY PHA_CODE  \
# 6556  39.974478 -75.177185                R    PA002
# 4366  39.974478 -75.177185                R    PA002
# 3298  39.974478 -75.177185                R    PA002
#
#                             PHA_NAME  INSPECTION_SCORE     INSPECTION_DATE  \
# 6556  Philadelphia Housing Authority                58 2016-02-22 00:00:00
# 4366  Philadelphia Housing Authority                46 2017-07-10 00:00:00
# 3298  Philadelphia Housing Authority                84 2018-11-05 08:52:59
#
#                 ADDRESS       ZIP
# 6556  2501 N College Ave  19121.0
# 4366  2501 N College Ave  19121.0
# 3298                 NaN      NaN

# %% [markdown]
# This development has actually gotten a better score in 2018 and two bad scores in 2016 and 2017.
